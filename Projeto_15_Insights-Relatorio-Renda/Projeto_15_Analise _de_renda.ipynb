# %% [markdown]
# # Módulo 10 atividade 1

# %% [markdown]
# Uma instituição financeira quer conhecer melhor o perfil de renda de seus novos clientes para diversos fins, por exemplo, melhor dimensionar o limite de cartões de crédito dos novos clientes, sem necessariamente solicitar olerites ou documentações que impactem na experiência do seu cliente.
#
# Para isto, conduziu um estudo com alguns clientes, comprovando suas rendas através de olerites e outros documentos, e pretende construir um modelo preditivo para esta renda com base em algumas variáveis que já possui em seu banco de dados.
#
# As variáveis são intuitivas - note que há uma variável 'index' que é um identificador do cliente e que em geral o ```read_csv``` do pandas coloca também uma variável sequencial.
#
# Estes dados estão no arquivo ```previsao_de_renda.csv```. Carregue-o em um *dataframe*.
#
# 1) Avalie a estrutura de correlação das variáveis quantitativas através de um gráfico de "matriz de dispersão" e através da avaliação gráfica da matriz de correlações. Veja se você identifica algum padrão interessante ou que te faça sentido.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar o arquivo CSV
df = pd.read_csv('previsao_de_renda.csv')

# Exibir as primeiras linhas do DataFrame
df.head()

# Selecionar apenas as colunas numéricas do DataFrame
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Matriz de dispersão das variáveis quantitativas
sns.pairplot(numeric_df)
plt.show()

# Matriz de correlação
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_df.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
import pandas as pd

# Carregar o arquivo CSV
df = pd.read_csv('previsao_de_renda.csv')

# Exibir as primeiras 10 linhas do DataFrame
print("Primeiras linhas do DataFrame:")
print(df.head(10))  # Imprime as primeiras 10 linhas dos dados

# Selecionar apenas as colunas numéricas do DataFrame
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Exibir a matriz de correlação das variáveis numéricas
print("\nMatriz de correlação:")
print(numeric_df.corr())
# Out:
# Primeiras linhas do DataFrame:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
# 5           5  2015-01-01   7409    M             False             True
# 6           6  2015-01-01   6913    F             False             True
# 7           7  2015-01-01  13047    M              True             True
# 8           8  2015-01-01   4529    F             False            False
# 9           9  2015-01-01  14646    F             False             True
#
#    qtd_filhos        tipo_renda             educacao estado_civil  \
# ...

# %% [markdown]
# 2) Avalie um gráfico de dispersão (*scatterplot*) específico para as duas variáveis mais correlacionadas com *renda*.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Gráfico de dispersão entre tempo_emprego e renda
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['tempo_emprego'], y=df['renda'])
plt.title('Relação entre Tempo de Emprego e Renda')
plt.xlabel('Tempo de Emprego (em anos)')
plt.ylabel('Renda')
plt.show()

# Imprimindo os valores de tempo_emprego e renda
print("Valores de tempo_emprego e renda:")
print(df[['tempo_emprego', 'renda']].tail())  # Exibe os últimos valores

# Gráfico de dispersão entre idade e renda
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['idade'], y=df['renda'])
plt.title('Relação entre Idade e Renda')
plt.xlabel('Idade (em anos)')
plt.ylabel('Renda')
plt.show()

# Imprimindo os valores de idade e renda
print("Valores de idade e renda:")
print(df[['idade', 'renda']].tail())  # Exibe os últimos valores
# Out:
# Valores de tempo_emprego e renda:
#        tempo_emprego    renda
# 14995       2.046575  1193.29
# 14996      12.079452  2519.18
# 14997       2.161644  1586.85
# 14998       3.295890  6975.39
# 14999       3.049315   993.86
# Valores de idade e renda:
#        idade    renda
# 14995     37  1193.29
# 14996     30  2519.18
# 14997     40  1586.85
# 14998     47  6975.39
# 14999     50   993.86

# %% [markdown]
# 3) Na su aopinião, há outliers na variável renda?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Carregar o arquivo CSV
df = pd.read_csv('previsao_de_renda.csv')

# Exibir as primeiras linhas do DataFrame
print("Primeiras linhas do DataFrame:")
print(df.head())

# 1. Boxplot da variável renda
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['renda'])
plt.title('Boxplot da Renda')
plt.xlabel('Renda')
plt.grid(True)
plt.show()

# 2. Histograma da variável renda
plt.figure(figsize=(8, 6))
sns.histplot(df['renda'], bins=30, kde=True)
plt.title('Histograma da Renda')
plt.xlabel('Renda')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()

# 3. Print dos dados da variável Renda
print("Dados da variável Renda:")
print(df['renda'])

# 4. Estatísticas descritivas da renda
renda_stats = df['renda'].describe()
print("\nEstatísticas Descritivas da Renda:")
print(renda_stats)

# 5. Análise de correlação
correlation_matrix = df[['renda', 'tempo_emprego', 'idade']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlação entre Renda, Tempo de Emprego e Idade')
plt.show()

# 6. Print da matriz de correlação
print("\nMatriz de Correlação:")
print(correlation_matrix)

# 7. Histograma da variável renda (repetido)
plt.figure(figsize=(8, 6))
sns.histplot(df['renda'], bins=30, kde=True)
plt.title('Distribuição da Renda')
plt.xlabel('Renda')
plt.ylabel('Frequência')
plt.grid(True)
plt.show()
# Out:
# Primeiras linhas do DataFrame:
#    Unnamed: 0    data_ref  index sexo  posse_de_veiculo  posse_de_imovel  \
# 0           0  2015-01-01   8682    F             False             True
# 1           1  2015-01-01  12830    M              True             True
# 2           2  2015-01-01   2885    M              True             True
# 3           3  2015-01-01  16168    F              True            False
# 4           4  2015-01-01  12438    M             False            False
#
#    qtd_filhos   tipo_renda           educacao estado_civil tipo_residencia  \
# 0           1  Assalariado         Secundário       Casado            Casa
# 1           0   Empresário         Secundário       Casado            Casa
# 2           2  Assalariado  Superior completo       Casado            Casa
# 3           0   Empresário         Secundário       Casado            Casa
# 4           0  Assalariado         Secundário       Casado            Casa
#
# ...

# %% [markdown]
# 4) Calcule o logaritmo da variável renda e repita a sequência de análise

# %%
# Calcular o logaritmo da variável renda
df['log_renda'] = np.log(df['renda'])

# Boxplot da variável log_renda
plt.figure(figsize=(8, 6))
sns.boxplot(x=df['log_renda'])
plt.title('Boxplot do Logaritmo da Renda')
plt.xlabel('Log(Renda)')
plt.show()

# Histograma da variável log_renda
plt.figure(figsize=(8, 6))
sns.histplot(df['log_renda'], bins=30, kde=True)
plt.title('Histograma do Logaritmo da Renda')
plt.xlabel('Log(Renda)')
plt.ylabel('Frequência')
plt.show()

# Print dos dados da variável log_renda
print("Dados da variável Log(Renda):")
print(df['log_renda'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# Dados da variável Log(Renda):
# 0        8.122442
# 1        8.715411
# 2        8.640999
# 3        8.888300
# 4        8.298383
#            ...
# 14995    7.084469
# 14996    7.831689
# 14997    7.369506
# 14998    8.850144
# 14999    6.901596
# Name: log_renda, Length: 15000, dtype: float64

# %% [markdown]
# 5) A aplicação do LOG você acha que melhorou ou piorou a análise?

# %% [markdown]
# A aplicação do logaritmo na variável `renda` parece ter melhorado a análise. A transformação reduziu a assimetria da distribuição e pode ter facilitado a identificação de padrões. Além disso, a visualização dos dados transformados permite uma interpretação mais clara dos resultados. Portanto, a aplicação do logaritmo é benéfica para esta análise.

# %% [markdown]
# # Relatório de Análise de Renda - Ciência de Dados
#
# ## 1. Descrição do DataFrame
# O DataFrame analisado contém 15.000 observações com variáveis relacionadas ao perfil de renda dos clientes de uma instituição financeira. As variáveis incluem:
# - **Idade**, **Tempo de Emprego**, **Posse de Veículo**, **Posse de Imóvel**, **Número de Filhos**, **Renda**, entre outras. A renda dos clientes é a principal variável de interesse.
#
# ### Primeiras Linhas do DataFrame:
#
# | index | data_ref  | sexo | posse_de_veiculo | posse_de_imovel | qtd_filhos | tipo_renda | educacao | estado_civil | tipo_residencia | idade | tempo_emprego | qt_pessoas_residencia | mau  | renda   |
# |-------|-----------|------|------------------|-----------------|------------|------------|----------|--------------|-----------------|-------|---------------|----------------------|------|---------|
# | 0     | 2015-01-01| F    | False            | True            | 1          | Assalariado| Secundário| Casado       | Casa            | 36    | 3.57          | 3.0                  | False| 3369.24 |
# | 1     | 2015-01-01| M    | True             | True            | 0          | Empresário | Secundário| Casado       | Casa            | 42    | 0.86          | 2.0                  | False| 6096.14 |
# | 2     | 2015-01-01| M    | True             | True            | 2          | Assalariado| Superior completo| Casado   | Casa            | 31    | 8.06          | 4.0                  | False| 5658.98 |
#
# ---
#
# ## 2. Matriz de Correlação
# A matriz de correlação identifica relações entre variáveis numéricas. As duas variáveis com maior correlação com **renda** são:
# - **tempo_emprego**: correlação de **0.39**
# - **idade**: correlação de **0.04**
#
# ### Matriz de Correlação (Simplificada):
#
# | Variável           | Correlação com Renda |
# |--------------------|----------------------|
# | Tempo de Emprego    | 0.39                 |
# | Idade              | 0.04                 |
#
# ---
#
# ## 3. Análise Gráfica
#
# ### a) Gráfico de Dispersão: Tempo de Emprego x Renda
# O gráfico de dispersão entre o **tempo de emprego** e a **renda** mostra uma correlação positiva moderada. Isso sugere que, em média, clientes com mais tempo de emprego tendem a ter uma renda maior.
#
# ### b) Gráfico de Dispersão: Idade x Renda
# O gráfico de dispersão entre **idade** e **renda** apresenta uma correlação mais fraca. Apesar de certa variação, a renda não parece aumentar substancialmente com a idade.
#
# ---
#
# ## 4. Análise de Outliers
# Com base nas distribuições analisadas, a variável **renda** apresenta outliers, observados principalmente nas rendas mais altas. Esses outliers podem influenciar a análise, distorcendo as tendências gerais.
#
# ---
#
# ## 5. Aplicação do Logaritmo
# A aplicação do logaritmo na variável **renda** resultou em uma distribuição mais simétrica, facilitando a visualização de padrões e a interpretação dos resultados.
#
# ### Exemplo de Dados com Log(Renda):
#
# | index | log_renda |
# |-------|-----------|
# | 0     | 8.12      |
# | 1     | 8.71      |
# | 2     | 8.64      |
# | 3     | 8.89      |
#
# ### Melhorias na Análise:
# A transformação logarítmica tornou a análise mais eficiente, especialmente em termos de visualização gráfica e modelagem preditiva. Reduziu a assimetria da variável e permitiu uma análise mais robusta dos dados.
#
# ---
#
# ## Conclusão
# A análise indica que **tempo de emprego** tem a maior correlação com **renda**, enquanto a **idade** possui uma relação mais fraca. A transformação logarítmica na variável renda foi benéfica, permitindo uma interpretação mais clara e consistente dos resultados.
